# %%
# import pandas as pd
from pandasgui import show
import pandas as pd
# Out:
# PandasGUI ERROR — pandasgui.store — name 'sess' is not defined
# Traceback (most recent call last):
#   File "c:\Users\arturoV\AppData\Local\miniconda3\envs\visualization\Lib\site-packages\pandas\core\computation\scope.py", line 231, in resolve
#     return self.resolvers[key]
#            ~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\arturoV\AppData\Local\miniconda3\envs\visualization\Lib\collections\__init__.py", line 1014, in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\arturoV\AppData\Local\miniconda3\envs\visualization\Lib\collections\__init__.py", line 1006, in __missing__
#     raise KeyError(key)
# KeyError: 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\arturoV\AppData\Local\miniconda3\envs\visualization\Lib\site-packages\pandas\core\computation\scope.py", line 242, in resolve
# ...

# %%
raw_matrix_df_thr_0_1=pd.read_excel('analysed/tables/raw_matrix_df_thr_0.1.xlsx')

# %%
capture_df=pd.read_excel('capture_df.xlsx')

# %%
show(raw_matrix_df_thr_0_1,capture_df)
# show(raw_matrix_df_thr_0)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# C:\Users\arturoV\AppData\Local\Temp\ipykernel_34664\383630489.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   show(raw_matrix_df_thr_0_1,capture_df)
# C:\Users\arturoV\AppData\Local\Temp\ipykernel_34664\383630489.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   show(raw_matrix_df_thr_0_1,capture_df)
# C:\Users\arturoV\AppData\Local\Temp\ipykernel_34664\383630489.py:1: FutureWarning:
#
# ...
